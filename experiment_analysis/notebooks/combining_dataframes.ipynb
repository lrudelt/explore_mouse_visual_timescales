# %%
# ------------------------------------------------------------------------------ #
# @Author:        F. Paul Spitzner
# @Email:         paul.spitzner@ds.mpg.de
# @Created:       2023-08-04 11:59:06
# @Last Modified: 2023-08-04 11:59:15
# ------------------------------------------------------------------------------ #
# This notebook shows how to combine three sources of data needed to get
# one dataframe that has everything. (@ps -> make a helper function?)
# - load spikes from multiple hdf5 files, recursively.
# - load analysis results of the hdestimator and mrestimator dataframe
# - load metrics from the allan institute csv files
#
# This was needed because dumping spike-times in our currently chosen format
# in an all-you can-eat hdf5 dataframe was not possible.
# ------------------------------------------------------------------------------ #

# %reload_ext autoreload
# %autoreload 2
# %reload_ext ipy_dict_hierarchy
# %reload_ext watermark

import logging
logging.basicConfig(
    format="%(asctime)s | %(levelname)-8s | %(name)-s > %(funcName)-s > %(message)s",
    level=logging.WARNING,
)
log = logging.getLogger("notebook")
log.setLevel("DEBUG")

import re
import glob
import h5py
import sys
import os
import numpy as np
import xarray as xr
import pandas as pd
import dask

from tqdm import tqdm


# also needs to be added for each dask-worker
extra_path = os.path.abspath('../')
sys.path.append(extra_path)
log.info(f"project directory: {extra_path}")

from ana import utility as utl
# utl.log.setLevel("DEBUG")
# Out:
# 2023-08-14 10:55:21,326 | INFO     | notebook > <module> > project directory: /Users/paul/para/2_Projects/information_timescales/repo/_latest/experiment_analysis

# %%
# utl.log.setLevel("DEBUG")
# specify the path as closely as possible, we search recursively through all subdirs
data_dir = "../../../gnode/experiment_analysis/dat/"
meta_df = utl.all_unit_metadata(data_dir, reload=False)
meta_df = utl.load_spikes(meta_df)
meta_df = utl.default_filter(meta_df, trim=False)
meta_df = utl.merge_blocks(meta_df)
meta_df
# Out:
# 2023-08-14 10:55:22,461 | DEBUG    | its_utility > all_unit_metadata > Found 61 hdf5 files in /Users/paul/para/2_Projects/information_timescales/repo/gnode/experiment_analysis/dat
# Fetching metadata from sessions:   0%|          | 0/61 [00:00<?, ?it/s]2023-08-14 10:55:22,477 | INFO     | its_utility > all_unit_metadata > Skipping /Users/paul/para/2_Projects/information_timescales/repo/gnode/experiment_analysis/dat/meta_df_final.h5. This might be a hdf5 file with no session data.
# 2023-08-14 10:55:22,479 | INFO     | its_utility > all_unit_metadata > Skipping /Users/paul/para/2_Projects/information_timescales/repo/gnode/experiment_analysis/dat/meta_df_merged_final.h5. This might be a hdf5 file with no session data.
# 2023-08-14 10:55:22,480 | INFO     | its_utility > all_unit_metadata > Skipping /Users/paul/para/2_Projects/information_timescales/repo/gnode/experiment_analysis/dat/meta_df_2_final.h5. This might be a hdf5 file with no session data.
# Fetching metadata from sessions: 100%|██████████| 61/61 [00:01<00:00, 58.29it/s]
# 2023-08-14 10:55:23,545 | DEBUG    | its_utility > load_spikes > Loading spikes for 12584 units, 31190 rows for pandas dataframe.
# Loading spikes for sessions: 100%|██████████| 58/58 [00:36<00:00,  1.59it/s]
# 2023-08-14 10:55:59,920 | WARNING  | its_utility > default_filter > Some units already have invalid_spiketimes_check, we overwrite.
# 2023-08-14 10:55:59,928 | DEBUG    | its_utility > default_filter > Default quality checks, valid rows before: 31190
# 2023-08-14 10:55:59,932 | DEBUG    | its_utility > default_filter > After rate check: 31120
# 2023-08-14 10:55:59,936 | DEBUG    | its_utility > default_filter > After zero-length check: 31120
# 2023-08-14 10:55:59,950 | DEBUG    | its_utility > default_filter > After minmum-duration check: 17689
# 2023-08-14 10:55:59,956 | DEBUG    | its_utility > default_filter > Excluded 376 / 12044 units for stimulus natural_movie_one_more_repeats
# 2023-08-14 10:55:59,960 | DEBUG    | its_utility > default_filter > Excluded 1 / 6022 units for stimulus spontaneous
# 2023-08-14 10:55:59,964 | DEBUG    | its_utility > default_filter > Excluded 13124 / 13124 units for stimulus natural_movie_three
# Merging blocks for units: 100%|██████████| 18606/18606 [00:36<00:00, 505.22it/s]
# 2023-08-14 10:56:37,291 | DEBUG    | its_utility > merge_blocks > Did not merge 6107 units (only found in one block). 12499 units remained.
#          session                        stimulus               block  \
# 0      787025148  natural_movie_one_more_repeats                 3.0
# 1      787025148  natural_movie_one_more_repeats                 3.0
# 2      787025148  natural_movie_one_more_repeats                 3.0
# 3      787025148  natural_movie_one_more_repeats                 3.0
# 4      787025148  natural_movie_one_more_repeats                 3.0
# ...          ...                             ...                 ...
# 43684  847657808  natural_movie_one_more_repeats  merged_3.0_and_8.0
# 43685  847657808  natural_movie_one_more_repeats  merged_3.0_and_8.0
# 43686  847657808  natural_movie_one_more_repeats  merged_3.0_and_8.0
# 43687  847657808  natural_movie_one_more_repeats  merged_3.0_and_8.0
# 43688  847657808  natural_movie_one_more_repeats  merged_3.0_and_8.0
#
#          unit_id ecephys_structure_acronym invalid_spiketimes_check  \
# 0      951013153                     VISam                  SUCCESS
# 1      951013143                     VISam                  SUCCESS
# 2      951013133                     VISam                  SUCCESS
# 3      951013202                     VISam                  SUCCESS
# 4      951013187                     VISam                  SUCCESS
# ...          ...                       ...                      ...
# 43684  951190716                        LP                  SUCCESS
# 43685  951190722                        LP                  SUCCESS
# 43686  951190724                        LP                  SUCCESS
# 43687  951190819                        LP                  SUCCESS
# 43688  951190848                     VISrl                  SUCCESS
#
#        recording_length  firing_rate  \
# 0            900.668806    21.542880
# 1            900.718039    11.652925
# 2            894.867666     0.448111
# 3            900.265072     2.384853
# 4            896.074534     0.706414
# ...                 ...          ...
# 43684       1067.306152     3.486347
# 43685       1077.341553     2.770709
# 43686       1076.488525     2.043682
# 43687       1075.182861     2.104758
# 43688       1071.963867     0.806930
#
#                                                 filepath  num_spikes  \
# 0      /Users/paul/para/2_Projects/information_timesc...       19403
# 1      /Users/paul/para/2_Projects/information_timesc...       10496
# 2      /Users/paul/para/2_Projects/information_timesc...         401
# 3      /Users/paul/para/2_Projects/information_timesc...        2147
# 4      /Users/paul/para/2_Projects/information_timesc...         633
# ...                                                  ...         ...
# 43684  /Users/paul/para/2_Projects/information_timesc...        3721
# 43685  /Users/paul/para/2_Projects/information_timesc...        2985
# 43686  /Users/paul/para/2_Projects/information_timesc...        2200
# 43687  /Users/paul/para/2_Projects/information_timesc...        2263
# 43688  /Users/paul/para/2_Projects/information_timesc...         865
#
#                                               spiketimes
# 0      [[[<xarray.DataArray (spiketimes: 30719)>\narr...
# 1      [[[<xarray.DataArray (spiketimes: 30719)>\narr...
# 2      [[[<xarray.DataArray (spiketimes: 30719)>\narr...
# 3      [[[<xarray.DataArray (spiketimes: 30719)>\narr...
# 4      [[[<xarray.DataArray (spiketimes: 30719)>\narr...
# ...                                                  ...
# 43684  [<xarray.DataArray ()>\narray(3.1584473, dtype...
# 43685  [<xarray.DataArray ()>\narray(0.40185547, dtyp...
# 43686  [<xarray.DataArray ()>\narray(1.0895996, dtype...
# 43687  [<xarray.DataArray ()>\narray(1.2353516, dtype...
# 43688  [<xarray.DataArray ()>\narray(1.5703125, dtype...
#
# [43689 rows x 11 columns]

# %%
analysed_df = pd.read_hdf(f"{data_dir}/meta_df_merged_final.h5", "/meta_df")
analysed_df
# Out:
#                                                                       ecephys_structure_acronym  \
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                                    VISam
# 950987344 natural_movie_one_more_repeats 774875821 3.0                                    VISam
# 950987340 natural_movie_one_more_repeats 774875821 3.0                                    VISam
# 950987352 natural_movie_one_more_repeats 774875821 3.0                                    VISam
# 950987362 natural_movie_one_more_repeats 774875821 3.0                                    VISam
# ...                                                                                         ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0                      VISp
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0                      VISl
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0                     VISam
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0                     VISam
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0                      VISl
#
#                                                                       invalid_spiketimes_check  \
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                                 SUCCESS
# 950987344 natural_movie_one_more_repeats 774875821 3.0                                 SUCCESS
# 950987340 natural_movie_one_more_repeats 774875821 3.0                                 SUCCESS
# 950987352 natural_movie_one_more_repeats 774875821 3.0                                 SUCCESS
# 950987362 natural_movie_one_more_repeats 774875821 3.0                                 SUCCESS
# ...                                                                                        ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0                  SUCCESS
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0                  SUCCESS
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0              ERR_REC_LEN
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0              ERR_REC_LEN
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0              ERR_REC_LEN
#
#                                                                        recording_length  \
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                       898.087879
# 950987344 natural_movie_one_more_repeats 774875821 3.0                       898.868180
# 950987340 natural_movie_one_more_repeats 774875821 3.0                       900.287381
# 950987352 natural_movie_one_more_repeats 774875821 3.0                       894.181973
# 950987362 natural_movie_one_more_repeats 774875821 3.0                       900.613482
# ...                                                                                 ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0        818.458008
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0        913.291992
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0        957.861328
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0        863.650879
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0        781.838623
#
#                                                                        firing_rate  \
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                    1.999804
# 950987344 natural_movie_one_more_repeats 774875821 3.0                    0.837720
# 950987340 natural_movie_one_more_repeats 774875821 3.0                    1.568388
# 950987352 natural_movie_one_more_repeats 774875821 3.0                    0.542395
# 950987362 natural_movie_one_more_repeats 774875821 3.0                    2.053045
# ...                                                                            ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0     0.058647
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0     0.174095
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0     0.220282
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0     1.269031
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0     0.474522
#
#                                                                                                                 filepath  \
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                 /data.nst/share/data/allen_visual_coding_neuro...
# 950987344 natural_movie_one_more_repeats 774875821 3.0                 /data.nst/share/data/allen_visual_coding_neuro...
# 950987340 natural_movie_one_more_repeats 774875821 3.0                 /data.nst/share/data/allen_visual_coding_neuro...
# 950987352 natural_movie_one_more_repeats 774875821 3.0                 /data.nst/share/data/allen_visual_coding_neuro...
# 950987362 natural_movie_one_more_repeats 774875821 3.0                 /data.nst/share/data/allen_visual_coding_neuro...
# ...                                                                                                                  ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0  /data.nst/share/data/allen_visual_coding_neuro...
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0  /data.nst/share/data/allen_visual_coding_neuro...
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  /data.nst/share/data/allen_visual_coding_neuro...
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  /data.nst/share/data/allen_visual_coding_neuro...
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  /data.nst/share/data/allen_visual_coding_neuro...
#
#                                                                        num_spikes  \
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                       1796
# 950987344 natural_movie_one_more_repeats 774875821 3.0                        753
# 950987340 natural_movie_one_more_repeats 774875821 3.0                       1412
# 950987352 natural_movie_one_more_repeats 774875821 3.0                        485
# 950987362 natural_movie_one_more_repeats 774875821 3.0                       1849
# ...                                                                           ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0          48
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0         159
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0         211
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0        1096
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0         371
#
#                                                                           R_tot  \
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                 0.028897
# 950987344 natural_movie_one_more_repeats 774875821 3.0                 0.254426
# 950987340 natural_movie_one_more_repeats 774875821 3.0                 0.039074
# 950987352 natural_movie_one_more_repeats 774875821 3.0                 0.074347
# 950987362 natural_movie_one_more_repeats 774875821 3.0                 0.037868
# ...                                                                         ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0  0.011261
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0  0.094832
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  0.159574
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  0.126121
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  0.249277
#
#                                                                           tau_R  \
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                 0.292095
# 950987344 natural_movie_one_more_repeats 774875821 3.0                 0.016040
# 950987340 natural_movie_one_more_repeats 774875821 3.0                 0.057306
# 950987352 natural_movie_one_more_repeats 774875821 3.0                 0.126436
# 950987362 natural_movie_one_more_repeats 774875821 3.0                 0.110199
# ...                                                                         ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0  0.000000
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0  0.075662
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  0.230245
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  0.178080
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  0.071127
#
#                                                                        tau_single  \
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                   2.204573
# 950987344 natural_movie_one_more_repeats 774875821 3.0                   0.049767
# 950987340 natural_movie_one_more_repeats 774875821 3.0                   0.263706
# 950987352 natural_movie_one_more_repeats 774875821 3.0                   0.657249
# 950987362 natural_movie_one_more_repeats 774875821 3.0                   0.778819
# ...                                                                           ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0    5.241771
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0    0.136336
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0    1.579377
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0    1.103750
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0    0.531974
#
#                                                                        tau_double  \
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                   2.204866
# 950987344 natural_movie_one_more_repeats 774875821 3.0                   0.045802
# 950987340 natural_movie_one_more_repeats 774875821 3.0                   0.233516
# 950987352 natural_movie_one_more_repeats 774875821 3.0                   0.594182
# 950987362 natural_movie_one_more_repeats 774875821 3.0                   0.749355
# ...                                                                           ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0    0.001162
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0    0.115506
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0    1.579400
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0    0.676409
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0    0.385120
#
#                                                                                                            tau_R_details  \
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                 {'firing_rate': 1.9997995746528745, 'firing_ra...
# 950987344 natural_movie_one_more_repeats 774875821 3.0                 {'firing_rate': 0.8332684370376139, 'firing_ra...
# 950987340 natural_movie_one_more_repeats 774875821 3.0                 {'firing_rate': 1.5594974952515301, 'firing_ra...
# 950987352 natural_movie_one_more_repeats 774875821 3.0                 {'firing_rate': 0.5412750157965074, 'firing_ra...
# 950987362 natural_movie_one_more_repeats 774875821 3.0                 {'firing_rate': 2.036386247175541, 'firing_rat...
# ...                                                                                                                  ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0  {'firing_rate': 0.05864672677956161, 'firing_r...
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0  {'firing_rate': 0.1740948981435352, 'firing_ra...
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  {'firing_rate': 0.22028156368590562, 'firing_r...
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  {'firing_rate': 1.2690252473499257, 'firing_ra...
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  {'firing_rate': 0.47324260718305533, 'firing_r...
#
#                                                                                                       tau_single_details  \
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                 {'tau': 2.2045730546241966, 'mre': 0.997734557...
# 950987344 natural_movie_one_more_repeats 774875821 3.0                 {'tau': 0.04976678697174655, 'mre': 0.90441349...
# 950987340 natural_movie_one_more_repeats 774875821 3.0                 {'tau': 0.26370610494040975, 'mre': 0.98121811...
# 950987352 natural_movie_one_more_repeats 774875821 3.0                 {'tau': 0.6572492090313748, 'mre': 0.992421399...
# 950987362 natural_movie_one_more_repeats 774875821 3.0                 {'tau': 0.7788194682871189, 'mre': 0.993600590...
# ...                                                                                                                  ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0  {'tau': 5.2417714824133785, 'mre': 0.999046578...
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0  {'tau': 0.13633607252766394, 'mre': 0.96399026...
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  {'tau': 1.5793768186950516, 'mre': 0.996839200...
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  {'tau': 1.1037496155641024, 'mre': 0.995480232...
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  {'tau': 0.5319743550605898, 'mre': 0.990645082...
#
#                                                                                                       tau_double_details
# unit_id   stimulus                       session   block
# 950987325 natural_movie_one_more_repeats 774875821 3.0                 {'tau': 2.2048661904516664, 'mre': 0.997734858...
# 950987344 natural_movie_one_more_repeats 774875821 3.0                 {'tau': 0.04580227717841129, 'mre': 0.89658257...
# 950987340 natural_movie_one_more_repeats 774875821 3.0                 {'tau': 0.23351615919178326, 'mre': 0.97881581...
# 950987352 natural_movie_one_more_repeats 774875821 3.0                 {'tau': 0.5941821956040216, 'mre': 0.991620379...
# 950987362 natural_movie_one_more_repeats 774875821 3.0                 {'tau': 0.7493554822530509, 'mre': 0.993349810...
# ...                                                                                                                  ...
# 951127614 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0  {'tau': 0.0011617555281603106, 'mre': 0.013516...
# 951128175 natural_movie_one_more_repeats 839557629 merged_3.0_and_8.0  {'tau': 0.11550580320940909, 'mre': 0.95763567...
# 951185417 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  {'tau': 1.579400109924387, 'mre': 0.9968392468...
# 951185493 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  {'tau': 0.6764090276893551, 'mre': 0.992635276...
# 951188271 natural_movie_one_more_repeats 847657808 merged_3.0_and_8.0  {'tau': 0.3851201035847193, 'mre': 0.987100952...
#
# [43689 rows x 13 columns]

# %%
meta_df.set_index(analysed_df.index.names, inplace=True, drop=True)
meta_df = utl.strict_merge_dfs_by_index(meta_df, analysed_df)
meta_df.reset_index(inplace=True, drop=False)
# Out:
# 2023-08-14 10:59:30,056 | WARNING  | its_utility > strict_merge_dfs_by_index > Column filepath differs in 43689 rows.

# %%
utl.log.setLevel("DEBUG")
meta_df = utl.load_metrics(meta_df, data_dir)
# Out:
# 2023-08-14 11:00:29,910 | DEBUG    | its_utility > load_metrics > Loaded columns ['unit_id', 'g_dsi_dg', 'mod_idx_dg', 'image_selectivity_ns'] from /Users/paul/para/2_Projects/information_timescales/repo/gnode/experiment_analysis/dat/brain_observatory_unit_metrics_filtered.csv
# 2023-08-14 11:00:30,101 | DEBUG    | its_utility > load_metrics > Loaded columns ['unit_id', 'g_dsi_dg', 'mod_idx_dg'] from /Users/paul/para/2_Projects/information_timescales/repo/gnode/experiment_analysis/dat/functional_connectivity_analysis_metrics.csv
# 2023-08-14 11:00:30,102 | INFO     | its_utility > load_metrics > Column g_dsi_dg found in multiple dataframes.
# 2023-08-14 11:00:30,102 | INFO     | its_utility > load_metrics > Column mod_idx_dg found in multiple dataframes.
# 2023-08-14 11:00:30,104 | DEBUG    | its_utility > load_metrics > Matched 19671 rows from meta_df in /Users/paul/para/2_Projects/information_timescales/repo/gnode/experiment_analysis/dat/brain_observatory_unit_metrics_filtered.csv
# 2023-08-14 11:00:33,932 | DEBUG    | its_utility > load_metrics > Matched 24018 rows from meta_df in /Users/paul/para/2_Projects/information_timescales/repo/gnode/experiment_analysis/dat/functional_connectivity_analysis_metrics.csv
# 2023-08-14 11:00:33,933 | INFO     | its_utility > load_metrics > 2nd occurence of cols ['g_dsi_dg', 'mod_idx_dg'], ignoring values from /Users/paul/para/2_Projects/information_timescales/repo/gnode/experiment_analysis/dat/functional_connectivity_analysis_metrics.csv
